# %% [markdown]
# ## Part 1:
# Using data found in sales.csv perform the following tasks:
#
# 1. Standardized the Price column
# 2. Identify and remove outliers in the datasets

# %% [raw]
# Answer to Questions:
# 1. Describe how and where did you get your data.
# ANS: This data is obtained from the instructors sales.csv
#
# 2. What are the challenges you encountered in gathering data?
# ANS: There is not much challenging problems in gathering the data for this part because it is already provided.
#
# 3. What are the preprocessing techniques you used to clean the data?
# ANS: The pre-processing techniques done in this part is the removal of "," in the Price to make it a number. The next one is deleting values outside the normal standardized_price. Lastly, converting price to float in order for it to be computed and treated as a number.
#
# 4. Why did you perform those techniques?
# ANS: This techniques where perform to identiy with values in the csv files are necessary and related to each other. This deteting of rows outside its range will be treated as not necessary if it is way far behind. Instance, values with standardized_price greater than 5, it became 5 because values with standardized_price of 4 has 15 in total; thus,  the standardized values greater than 5 is not included anymore.

# %% [markdown]
# # Standardizing Column Values

# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv("Fradejas_sales.csv")
sales.describe(include="all")
# Out:
#        Transaction_date   Product Price Payment_Type   Name    City    State  \
# count               997       997   999          997   1000     996      995
# unique              979         4    12            4    761     752      204
# top      1/8/2009 15:27  Product1  1200         Visa  Sarah  London  England
# freq                  2       846   838          520     11      19       84
# mean                NaN       NaN   NaN          NaN    NaN     NaN      NaN
# std                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
# min                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
# 25%                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
# 50%                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
# 75%                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
# max                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
#
# ...

# %%
# remove "," in price
sales = sales.replace(',','', regex=True)

# %%
# convert data frame to float
sales['Price'] = sales['Price'].astype(float)

# %%
sales.describe(include="all")
# Out:
#        Transaction_date   Product         Price Payment_Type   Name    City  \
# count               997       997    999.000000          997   1000     996
# unique              979         4           NaN            4    761     752
# top      1/8/2009 15:27  Product1           NaN         Visa  Sarah  London
# freq                  2       846           NaN          520     11      19
# mean                NaN       NaN   1650.970971          NaN    NaN     NaN
# std                 NaN       NaN   1210.577115          NaN    NaN     NaN
# min                 NaN       NaN     20.000000          NaN    NaN     NaN
# 25%                 NaN       NaN   1200.000000          NaN    NaN     NaN
# 50%                 NaN       NaN   1200.000000          NaN    NaN     NaN
# 75%                 NaN       NaN   1200.000000          NaN    NaN     NaN
# max                 NaN       NaN  13000.000000          NaN    NaN     NaN
#
# ...

# %%
# insert new column for standardized price
sales.insert(3, "standardized_price", 0)

# %%
sales.standardized_price = (sales.Price - np.mean(sales.Price))/(np.std(sales.Price))

# %%
# look for uncommong values using values count
sales.standardized_price.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b9b02c002381> in <module>
#       1 # look for uncommong values using values count
# ----> 2 sales.standardized_price.value_counts().sort()
#
# NameError: name 'sales' is not defined

# %%
# drop values with standardized values greater than 5
sales_new = sales.drop(sales[sales['standardized_price'] > 5].index)

# %%
sales_new.standardized_price.value_counts()
# Out:
# -0.372712    838
#  1.610806    137
#  4.834024     15
# -1.157855      1
#  0.371107      1
# -1.347942      1
#  0.123167      1
# -0.331389      1
# -0.703299      1
# Name: standardized_price, dtype: int64

# %%
# new sales data removing unecessary columns 
sales_new.describe(include="all")
# Out:
#        Transaction_date   Product        Price  standardized_price  \
# count               994       994   996.000000          996.000000
# unique              976         4          NaN                 NaN
# top      1/8/2009 15:27  Product1          NaN                 NaN
# freq                  2       843          NaN                 NaN
# mean                NaN       NaN  1624.016064           -0.022277
# std                 NaN       NaN  1102.316855            0.911027
# min                 NaN       NaN    20.000000           -1.347942
# 25%                 NaN       NaN  1200.000000           -0.372712
# 50%                 NaN       NaN  1200.000000           -0.372712
# 75%                 NaN       NaN  1200.000000           -0.372712
# max                 NaN       NaN  7500.000000            4.834024
#
#        Payment_Type   Name    City    State        Country Account_Created  \
# count           994    997     993      992            997             994
# ...

# %% [markdown]
# ## Part 2:
# Using data found in sales.csv perform the following tasks:
#
# 1. Standardized the Price column
# 2. Identify and remove outliers in the datasets

# %% [raw]
# Answer to Questions:
# 1. Describe how and where did you get your data.
# ANS: This data is obtained from the instructors Handling Missing Values.csv
#
# 2. What are the challenges you encountered in gathering data?
# ANS: There is not much challenging problems in gathering the data for this part because it is already provided.
#
# 3. What are the preprocessing techniques you used to clean the data?
# ANS: The pre-processing made for this part is replacing values of Singles with children as "NaN" to 0. The next pre-processing method done is imputation of customers who has Age that is 18 with the mean values. The values are assumed and set because of the range of values seen for Age 28 contains income between 26 to 27K which the mean satisfied. Thus, all customers with Age 28 has been set to the mean. Lastly, rows with no income, who didn't buy a car, and with not sex is dropped because of lack of necesary data.
#
# 4. Why did you perform those techniques?
# ANS: The techniques where performed to normalize all the data so we can see the relationship between each data.

# %%
import pandas as pd
import numpy as np

values = pd.read_csv("Fradejas_missing_values.csv")
values.describe(include="all")
# Out:
#               ID   Sex        Age        Income Employed   Children Buy_Car
# count   20.00000    16  20.000000     17.000000       20  18.000000      20
# unique       NaN     2        NaN           NaN        2        NaN       2
# top          NaN  Male        NaN           NaN  Married        NaN      No
# freq         NaN    10        NaN           NaN       15        NaN      11
# mean    10.50000   NaN  28.150000  26245.705882      NaN   1.222222     NaN
# std      5.91608   NaN   1.308877    583.052395      NaN   1.437136     NaN
# min      1.00000   NaN  25.000000  25094.000000      NaN   0.000000     NaN
# 25%      5.75000   NaN  28.000000  26037.000000      NaN   0.000000     NaN
# 50%     10.50000   NaN  28.000000  26234.000000      NaN   1.000000     NaN
# 75%     15.25000   NaN  29.000000  26666.000000      NaN   2.000000     NaN
# max     20.00000   NaN  30.000000  26969.000000      NaN   4.000000     NaN

# %%
# print values
values
# Out:
#     ID     Sex  Age   Income Employed  Children Buy_Car
# 0    1    Male   25  25146.0   Single       0.0      No
# 1    2    Male   30  26939.0  Married       2.0     Yes
# 2    3    Male   27  26693.0  Married       0.0      No
# 3    4    Male   28  26666.0  Married       3.0     Yes
# 4    5    Male   29  25899.0  Married       0.0      No
# 5    6    Male   28  26462.0  Married       1.0      No
# 6    7  Female   28      NaN  Married       3.0     Yes
# 7    8     NaN   30  26037.0  Married       2.0     Yes
# 8    9  Female   28  26167.0  Married       1.0     Yes
# 9   10     NaN   28      NaN   Single       NaN      No
# 10  11  Female   28  26905.0   Single       0.0      No
# 11  12    Male   30  26195.0   Single       NaN     Yes
# 12  13  Female   30  26514.0  Married       4.0     Yes
# 13  14  Female   28  26969.0  Married       4.0     Yes
# 14  15     NaN   28  26234.0  Married       0.0      No
# 15  16    Male   27  26229.0  Married       0.0      No
# ...

# %%
# setting all children of 'Singles' to 0
values.loc[(values.Employed == 'Single'),'Children'] = 0
values
# Out:
#     ID     Sex  Age   Income Employed  Children Buy_Car
# 0    1    Male   25  25146.0   Single       0.0      No
# 1    2    Male   30  26939.0  Married       2.0     Yes
# 2    3    Male   27  26693.0  Married       0.0      No
# 3    4    Male   28  26666.0  Married       3.0     Yes
# 4    5    Male   29  25899.0  Married       0.0      No
# 5    6    Male   28  26462.0  Married       1.0      No
# 6    7  Female   28      NaN  Married       3.0     Yes
# 7    8     NaN   30  26037.0  Married       2.0     Yes
# 8    9  Female   28  26167.0  Married       1.0     Yes
# 9   10     NaN   28      NaN   Single       0.0      No
# 10  11  Female   28  26905.0   Single       0.0      No
# 11  12    Male   30  26195.0   Single       0.0     Yes
# 12  13  Female   30  26514.0  Married       4.0     Yes
# 13  14  Female   28  26969.0  Married       4.0     Yes
# 14  15     NaN   28  26234.0  Married       0.0      No
# 15  16    Male   27  26229.0  Married       0.0      No
# ...

# %%
# dropping index 10 for having no information and didn't buy a car
new_values = values.drop(9)
new_values
# Out:
#     ID     Sex  Age   Income Employed  Children Buy_Car
# 0    1    Male   25  25146.0   Single       0.0      No
# 1    2    Male   30  26939.0  Married       2.0     Yes
# 2    3    Male   27  26693.0  Married       0.0      No
# 3    4    Male   28  26666.0  Married       3.0     Yes
# 4    5    Male   29  25899.0  Married       0.0      No
# 5    6    Male   28  26462.0  Married       1.0      No
# 6    7  Female   28      NaN  Married       3.0     Yes
# 7    8     NaN   30  26037.0  Married       2.0     Yes
# 8    9  Female   28  26167.0  Married       1.0     Yes
# 10  11  Female   28  26905.0   Single       0.0      No
# 11  12    Male   30  26195.0   Single       0.0     Yes
# 12  13  Female   30  26514.0  Married       4.0     Yes
# 13  14  Female   28  26969.0  Married       4.0     Yes
# 14  15     NaN   28  26234.0  Married       0.0      No
# 15  16    Male   27  26229.0  Married       0.0      No
# 16  17  Female   26  25094.0  Married       0.0      No
# ...

# %%
# analyze values where there is NaN
new_values.isnull().sum()
# Out:
# ID          0
# Sex         3
# Age         0
# Income      2
# Employed    0
# Children    0
# Buy_Car     0
# dtype: int64

# %%
mean_value = new_values['Income'].mean()
mean_value
# Out:
# 26245.70588235294

# %%
new_values['Income'] = new_values['Income'].fillna(mean_value) # fill NaN values for Income

# %%
new_values
# Out:
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 0    1    Male   25  25146.000000   Single       0.0      No
# 1    2    Male   30  26939.000000  Married       2.0     Yes
# 2    3    Male   27  26693.000000  Married       0.0      No
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 4    5    Male   29  25899.000000  Married       0.0      No
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# 7    8     NaN   30  26037.000000  Married       2.0     Yes
# 8    9  Female   28  26167.000000  Married       1.0     Yes
# 10  11  Female   28  26905.000000   Single       0.0      No
# 11  12    Male   30  26195.000000   Single       0.0     Yes
# 12  13  Female   30  26514.000000  Married       4.0     Yes
# 13  14  Female   28  26969.000000  Married       4.0     Yes
# 14  15     NaN   28  26234.000000  Married       0.0      No
# ...

# %%
new_values[new_values['Age'] == 28]
# knowing the income of people with Age 28, we can safely say that the salary grade is between 26-27K, 
# and we can safely assume that the data we supplied is correct.
# Out:
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# 8    9  Female   28  26167.000000  Married       1.0     Yes
# 10  11  Female   28  26905.000000   Single       0.0      No
# 13  14  Female   28  26969.000000  Married       4.0     Yes
# 14  15     NaN   28  26234.000000  Married       0.0      No
# 17  18     NaN   28  26245.705882   Single       0.0     Yes
# 18  19    Male   28  26601.000000  Married       1.0      No

# %%
new_values # The sex will be kept because sex can be random
# Out:
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 0    1    Male   25  25146.000000   Single       0.0      No
# 1    2    Male   30  26939.000000  Married       2.0     Yes
# 2    3    Male   27  26693.000000  Married       0.0      No
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 4    5    Male   29  25899.000000  Married       0.0      No
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# 7    8     NaN   30  26037.000000  Married       2.0     Yes
# 8    9  Female   28  26167.000000  Married       1.0     Yes
# 10  11  Female   28  26905.000000   Single       0.0      No
# 11  12    Male   30  26195.000000   Single       0.0     Yes
# 12  13  Female   30  26514.000000  Married       4.0     Yes
# 13  14  Female   28  26969.000000  Married       4.0     Yes
# 14  15     NaN   28  26234.000000  Married       0.0      No
# ...

# %% [markdown]
# ## Part 3: Application
# 1. Gather Data From Any Source (it would be better if you use your own data)
# 2. Preprocess the data you gathered

# %% [raw]
# # some columns are deleted because of Data Privacy Act of 2012
#
# Answer to Questions:
# 1. Describe how and where did you get your data.
# ANS: This data is obtained from survey in RSU - IT students
#
# 2. What are the challenges you encountered in gathering data?
# ANS: Due to lack of validity in google forms who created it, there are lots of inconsistent data with the same value.
#
# 3. What are the preprocessing techniques you used to clean the data?
# ANS: First is remove the duplicates who submitted multiple forms. Next is deleting unecessary data with empy values and random letters. Next one is imputating values with leading spaces that causes data confusion
#
# 4. Why did you perform those techniques?
# ANS: The techniques performed on the form are necessary to process data and visual all the information needed by the Academic institution. Because of the data cleaning, the inconsistent data are removed that lead to more accurate reporting.

# %%
import pandas as pd
data = pd.read_csv("Fradejas_Student_Profiling.csv")

# %%
data = data.drop_duplicates(subset=['Last Name', 'First name']) # this code is used to drop all duplicate entries with the same 
                                                                # last name and first name

# %%
data = data.reset_index() # reset the indices 
data[data['HOME ADDRESS: Please enter the name of your PROVINCE'].str.contains('Romblon')] = 'Romblon' 
                          # setting all data to "Romblon" for conistency

# %%
data.describe(include="all")

# %% [markdown]
# ### Due to Data Privacy issues, I can't show you the whole code but this are some of the script used to clean the data
