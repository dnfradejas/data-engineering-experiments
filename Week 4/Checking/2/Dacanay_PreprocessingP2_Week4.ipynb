# %% [markdown]
# # Data Preprocessing Part 2 (SP702 PGA04)
# **Set assigned: Sales.csv ad Handling_Missing_Values.csv**
#
# Instructions are listed as markdowns below

# %% [markdown]
# **Guide Questions**
#
# 1. **Describe how and where did you get your data.**
#     * The Data I acquired for part 3 are the submissions of 50 respondents from my Survey on Convenience Stores for SP201: Excel Basics**
#
#
# 2. **What are the challenges you encountered in gathering data?**
#     * Multiple formats of string type entries that deviate from your intended format. For you to be able to group similar entries but with different formats, you must be able to standardize them. Finding a optimal way to standardize these formats is also a challenge.
#     * Ensuring that numbers fresh from surveys to not be interpreted as strings is also a challenge, as this can impact any arithmetic operations that are conducted prior to preprocessing.
#
#
# 3. **What are the preprocessing techniques you used to clean the data?**
#     * The following were used in preprocessing my own data:
#         * Defaulting NaN values to a constant 'Unemployed' since this was specified in the survey that if the respondent is unemployed, they are to respond with N/A on the City of Work item.
#         * City name standardization using replacements, unique() function for checking, and str.title() to display first letter capitalized.
#         * For the other data sets, standardization of continuous variables, using mean as a global constant for NaN continuous variables, and using an "unknown" global constant (with stated rational) were other techniques used in this exercise
#
#
# 4. **Why did you perform those techniques?**
#     * Standardization of the city names were needed in further exploratory analysis should residents from such cities need to be grouped together. And replacement of work city NaN's to unemployed was something the respondents were aware of when they were willing up thus it was appropriate to set this as a global constant for that column.

# %% [markdown]
# ### Part 0: importing the 3 Datasets
# The following datasets were imported:
# 1. sales.csv
# 2. Handling_Missing_Values.csv
# 3. RawData_SP201.csv

# %%
import pandas as pd
import numpy as np

data01 = pd.read_csv("sales.csv")
data02 = pd.read_csv("Handling_Missing_Values.csv")
data03 = pd.read_csv("RawData_SP201.csv")

# %% [markdown]
# ### Part 1:
# Using the Data found in sales.csv, perform the following tasks:
# 1. Standardize the Price Column
# 2. Identify and remove outliers in the dataset
#
# *Note: Based on the previous PGA, an item in the price column, "13,000", in index 560 is a string. We'll correct that.*

# %%
data01.head(10) ## Print file's first 10 entries
# Out:
#   Transaction_date   Product Price Payment_Type               Name  \
# 0    1/2/2009 6:17  Product1  1200   Mastercard           carolina
# 1    1/2/2009 4:53  Product1  1200         Visa             Betina
# 2   1/2/2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3   1/3/2009 14:44  Product1  1200         Visa              Gouya
# 4   1/4/2009 12:56  Product2  3600         Visa            Gerd W
# 5   1/4/2009 13:19  Product1  1200         Visa           LAURENCE
# 6   1/4/2009 20:11  Product1  1200   Mastercard              Fleur
# 7   1/2/2009 20:09  Product1  1200   Mastercard               adam
# 8   1/2/2009 20:09  Product1  1200   Mastercard               adam
# 9   1/4/2009 13:17  Product1  1200   Mastercard    Renee Elisabeth
#
#                            City     State         Country   Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/2009 6:00
# 1  Parkville                           MO   United States     1/2/2009 4:42
# 2  Astoria                             OR   United States    1/1/2009 16:21
# 3                        Echuca  Victoria       Australia   9/25/2005 21:13
# 4  Cahaba Heights                      AL   United States  11/15/2008 15:47
# 5  Mickleton                           NJ   United States   9/24/2008 15:19
# 6  Peoria                              IL   United States     1/3/2009 9:38
# 7  Martin                              TN   United States    1/2/2009 17:43
# 8  Martin                              TN   United States    1/2/2009 17:43
# 9                      Tel Aviv  Tel Aviv          Israel    1/4/2009 13:03
#
#        Last_Login   Latitude   Longitude
# 0   1/2/2009 6:08  51.500000   -1.116667
# 1   1/2/2009 7:49  39.195000  -94.681940
# 2  1/3/2009 12:32  46.188060 -123.830000
# 3  1/3/2009 14:22 -36.133333  144.750000
# 4  1/4/2009 12:45  33.520560  -86.802500
# 5  1/4/2009 13:04  39.790000  -75.238060
# 6  1/4/2009 19:45  40.693610  -89.588890
# 7  1/4/2009 20:01  36.343330  -88.850280
# 8  1/4/2009 20:01  36.343330  -88.850280
# 9  1/4/2009 22:10  32.066667   34.766667

# %%
print(data01[data01['Price']=='13,000'].dtypes)
# Out:
# Transaction_date     object
# Product              object
# Price                object
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# dtype: object

# %% [markdown]
# **We'll convert the string 13,000 by replacing the comma with a blank. Then convert the whole Price column to float**

# %%
data01['Price'].str.replace(",","").astype('float64')
##Successful conversion of 13,000 string to numerical.
# Out:
# 0      1200.0
# 1      1200.0
# 2      1200.0
# 3      1200.0
# 4      3600.0
#         ...
# 995    1200.0
# 996    3600.0
# 997    7500.0
# 998    1200.0
# 999    1200.0
# Name: Price, Length: 1000, dtype: float64

# %%
data01.insert(12,'std_sales',0) #insert a new column std_sales for standardized prices

# %%
##Standardization while converting price entries to float
data01.std_sales = (data01['Price'].str.replace(",","").astype(float)-\
                    np.mean(data01['Price'].str.replace(",","").astype(float)))\
                    /np.std(data01['Price'].str.replace(",","").astype(float))

data01.std_sales.describe()
# Out:
# count    9.990000e+02
# mean    -3.737417e-16
# std      1.000501e+00
# min     -1.347942e+00
# 25%     -3.727122e-01
# 50%     -3.727122e-01
# 75%     -3.727122e-01
# max      9.379587e+00
# Name: std_sales, dtype: float64

# %%
##Show Preview of standardization

data01[['Price','std_sales']]
# Out:
#     Price  std_sales
# 0    1200  -0.372712
# 1    1200  -0.372712
# 2    1200  -0.372712
# 3    1200  -0.372712
# 4    3600   1.610806
# ..    ...        ...
# 995  1200  -0.372712
# 996  3600   1.610806
# 997  7500   4.834024
# 998  1200  -0.372712
# 999  1200  -0.372712
#
# [1000 rows x 2 columns]

# %% [markdown]
# **Finding: Max Value is greater than 3 Standard Deviations. We eliminate that/those outlier/s.**

# %%
data01_toFile = data01[data01['std_sales']<3]
data01_toFile.to_csv('sales_new.csv',index = False) #write to file part 1 output

preview = pd.read_csv('sales_new.csv')
preview.head(10)
# Out:
#   Transaction_date   Product  Price Payment_Type               Name  \
# 0    1/2/2009 6:17  Product1   1200   Mastercard           carolina
# 1    1/2/2009 4:53  Product1   1200         Visa             Betina
# 2   1/2/2009 13:08  Product1   1200   Mastercard  Federica e Andrea
# 3   1/3/2009 14:44  Product1   1200         Visa              Gouya
# 4   1/4/2009 12:56  Product2   3600         Visa            Gerd W
# 5   1/4/2009 13:19  Product1   1200         Visa           LAURENCE
# 6   1/4/2009 20:11  Product1   1200   Mastercard              Fleur
# 7   1/2/2009 20:09  Product1   1200   Mastercard               adam
# 8   1/2/2009 20:09  Product1   1200   Mastercard               adam
# 9   1/4/2009 13:17  Product1   1200   Mastercard    Renee Elisabeth
#
#                            City     State         Country   Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/2009 6:00
# 1  Parkville                           MO   United States     1/2/2009 4:42
# 2  Astoria                             OR   United States    1/1/2009 16:21
# 3                        Echuca  Victoria       Australia   9/25/2005 21:13
# 4  Cahaba Heights                      AL   United States  11/15/2008 15:47
# 5  Mickleton                           NJ   United States   9/24/2008 15:19
# 6  Peoria                              IL   United States     1/3/2009 9:38
# 7  Martin                              TN   United States    1/2/2009 17:43
# 8  Martin                              TN   United States    1/2/2009 17:43
# 9                      Tel Aviv  Tel Aviv          Israel    1/4/2009 13:03
#
#        Last_Login   Latitude   Longitude  std_sales
# 0   1/2/2009 6:08  51.500000   -1.116667  -0.372712
# 1   1/2/2009 7:49  39.195000  -94.681940  -0.372712
# 2  1/3/2009 12:32  46.188060 -123.830000  -0.372712
# 3  1/3/2009 14:22 -36.133333  144.750000  -0.372712
# 4  1/4/2009 12:45  33.520560  -86.802500   1.610806
# 5  1/4/2009 13:04  39.790000  -75.238060  -0.372712
# 6  1/4/2009 19:45  40.693610  -89.588890  -0.372712
# 7  1/4/2009 20:01  36.343330  -88.850280  -0.372712
# 8  1/4/2009 20:01  36.343330  -88.850280  -0.372712
# 9  1/4/2009 22:10  32.066667   34.766667  -0.372712

# %% [markdown]
# ### Part 2:
# Using the Data in Handling_Missing_Values.csv:
# 1. Handle all the missing values. Provide an explanation for choosing the specific method (delete, impute, or keep: if impute, why mean, median, or mode?) in handling specific missing values
#
#
# * The following were actions taken in dealing with missing values:
#
#     * **Sex** - it was chosen to apply a global constant "Unkown" instead of a mode since these are impactful in a study. Thus, instead of assuming a 'sex'through mode(), 'unknown' is declared instead as these may have significantly different statistics with their corresponding attributes.
#
#     * **Income** - We use the mean of income for the missing data in this column
#
#     * **Children** - We use the median of No. of Children since it is a discrete variable.

# %%
data02 ## Print file's entries
# Out:
#     ID     Sex  Age   Income Employed  Children Buy_Car
# 0    1    Male   25  25146.0   Single       0.0      No
# 1    2    Male   30  26939.0  Married       2.0     Yes
# 2    3    Male   27  26693.0  Married       0.0      No
# 3    4    Male   28  26666.0  Married       3.0     Yes
# 4    5    Male   29  25899.0  Married       0.0      No
# 5    6    Male   28  26462.0  Married       1.0      No
# 6    7  Female   28      NaN  Married       3.0     Yes
# 7    8     NaN   30  26037.0  Married       2.0     Yes
# 8    9  Female   28  26167.0  Married       1.0     Yes
# 9   10     NaN   28      NaN   Single       NaN      No
# 10  11  Female   28  26905.0   Single       0.0      No
# 11  12    Male   30  26195.0   Single       NaN     Yes
# 12  13  Female   30  26514.0  Married       4.0     Yes
# 13  14  Female   28  26969.0  Married       4.0     Yes
# 14  15     NaN   28  26234.0  Married       0.0      No
# 15  16    Male   27  26229.0  Married       0.0      No
# 16  17  Female   26  25094.0  Married       0.0      No
# 17  18     NaN   28      NaN   Single       0.0     Yes
# 18  19    Male   28  26601.0  Married       1.0      No
# 19  20    Male   29  25427.0  Married       1.0      No

# %%
data02.describe() ##EDA checking the properties of the set
# Out:
#              ID        Age        Income   Children
# count  20.00000  20.000000     17.000000  18.000000
# mean   10.50000  28.150000  26245.705882   1.222222
# std     5.91608   1.308877    583.052395   1.437136
# min     1.00000  25.000000  25094.000000   0.000000
# 25%     5.75000  28.000000  26037.000000   0.000000
# 50%    10.50000  28.000000  26234.000000   1.000000
# 75%    15.25000  29.000000  26666.000000   2.000000
# max    20.00000  30.000000  26969.000000   4.000000

# %% [markdown]
# **Finding: it is worth nothing that the Age and Income have low spread of data given the range. We can apply mean for continuous variables and median for discrete variables.**

# %%
data02.mode(numeric_only = True).head(1) ## EDA Check the set's modes
# Out:
#    ID   Age   Income  Children
# 0   1  28.0  25094.0       0.0

# %%
data02.isnull().sum() #Check for counts of null values in each column
# Out:
# ID          0
# Sex         4
# Age         0
# Income      3
# Employed    0
# Children    2
# Buy_Car     0
# dtype: int64

# %%
##For Sex, it was chosen to apply a global constant "Unkown" instead of a mode since these \
## are impactful in a study. Thus, instead of assuming a 'sex', 'unknown' is declared instead \
## as these may have significantly different statistics with their corresponding attributes.
data02['Sex'] = data02['Sex'].fillna("Unkown")

##We use the mean of income for the missing data in this column
inc_mean = data02['Income'].mean()
data02['Income'] = data02['Income'].fillna(inc_mean)

##We use the median of No. of Children since it is a discrete variable.
children_median = data02['Children'].median()
data02['Children'] = data02['Children'].fillna(children_median) 

data02.to_csv('Handling_Missing_Values_new.csv', index = False)
preview = pd.read_csv('Handling_Missing_Values_new.csv')
preview
#No more NaN/Null cells
# Out:
#     ID     Sex  Age        Income Employed  Children Buy_Car
# 0    1    Male   25  25146.000000   Single       0.0      No
# 1    2    Male   30  26939.000000  Married       2.0     Yes
# 2    3    Male   27  26693.000000  Married       0.0      No
# 3    4    Male   28  26666.000000  Married       3.0     Yes
# 4    5    Male   29  25899.000000  Married       0.0      No
# 5    6    Male   28  26462.000000  Married       1.0      No
# 6    7  Female   28  26245.705882  Married       3.0     Yes
# 7    8  Unkown   30  26037.000000  Married       2.0     Yes
# 8    9  Female   28  26167.000000  Married       1.0     Yes
# 9   10  Unkown   28  26245.705882   Single       1.0      No
# 10  11  Female   28  26905.000000   Single       0.0      No
# 11  12    Male   30  26195.000000   Single       1.0     Yes
# 12  13  Female   30  26514.000000  Married       4.0     Yes
# 13  14  Female   28  26969.000000  Married       4.0     Yes
# 14  15  Unkown   28  26234.000000  Married       0.0      No
# 15  16    Male   27  26229.000000  Married       0.0      No
# 16  17  Female   26  25094.000000  Married       0.0      No
# 17  18  Unkown   28  26245.705882   Single       0.0     Yes
# 18  19    Male   28  26601.000000  Married       1.0      No
# 19  20    Male   29  25427.000000  Married       1.0      No

# %% [markdown]
# ### Part 3: Application
#
# 1. Gather Data from Any source (it would be better if you use your own data)
# 2. Preprocess the data you gathered

# %% [markdown]
# ### Data Dictionary (data from survey in SP201)
#
# **Age** - Age of Respondent
#
# **ConvStore_nearto** - Where are the convenience store/s you visit near to?
#
# **HomeProv_add** - Province of Residence
#
# **HomeCity_add** - City/Municipality of Residence
#
# **WorkProv_add** - Province of Work
#
# **WorkCity_add** - City/Municipality of Work
#
# **ConvStore_TD** - How far (in travel time) is the nearest convenience store?
#
# **ConvStoresVisited** - Which Convenience stores do you visit?
#
# **Frequency** - How frequent do you visit convenience stores?
#
# **Reasons** - For what reason/s do you visit a convenience store?
#
# **Environment** - Would you classify your place of residence to be rural or urban?
#
# **Nr_CityCenter** - Do you consider to be very near the city center? ( < 10 min walk)

# %%
data03.head(10) ## Print file's first 10 entries
# Out:
#    Age                                  ConvStoresVisited  \
# 0   33  7-Eleven, Family Mart, Ministop, Alfamart, Lawson
# 1   26                                           7-Eleven
# 2   25                         7-Eleven, Ministop, Lawson
# 3   24          7-Eleven, Family Mart, Ministop, Alfamart
# 4   27                    7-Eleven, Family Mart, Ministop
# 5   24                    7-Eleven, Family Mart, Ministop
# 6   35                    7-Eleven, Family Mart, Ministop
# 7   27            7-Eleven, Family Mart, Ministop, Lawson
# 8   30                       7-Eleven, Ministop, Alfamart
# 9   26                                 7-Eleven, Ministop
#
#                                            Frequency  \
# 0    Fair (Twice a week to more than twice a month.)
# 1    Fair (Twice a week to more than twice a month.)
# 2  Rarely (On occasion only and less than twice a...
# 3    Fair (Twice a week to more than twice a month.)
# 4    Fair (Twice a week to more than twice a month.)
# 5    Fair (Twice a week to more than twice a month.)
# 6                    Seldom (Twice a month  or less)
# 7  Rarely (On occasion only and less than twice a...
# 8                    Seldom (Twice a month  or less)
# 9        Often (Every day to more than twice a week)
#
#                                              Reasons  \
# 0  Purchase of Non-food/drink items, Purchase of ...
# 1   Purchase of food and drinks (consumed elsewhere)
# 2  Purchase of Non-food/drink items, Purchase of ...
# 3  Purchase of Non-food/drink items, Purchase of ...
# 4  Purchase of Non-food/drink items, Purchase of ...
# 5  Purchase of food and drinks (consumed elsewher...
# 6  Purchase of food and drinks (consumed elsewher...
# 7  Purchase of Non-food/drink items, Purchase of ...
# 8  Purchase of Non-food/drink items, Purchase of ...
# 9   Purchase of food and drinks (consumed elsewhere)
#
#                  ConvStore_nearto  HomeProv_add   HomeCity_add  WorkProv_add  \
# 0  Place of Work, Current Address  Metro Manila    Mandaluyong  Metro Manila
# 1                   Place of Work  Metro Manila  Caloocan City  Metro Manila
# 2  Place of Work, Current Address  Metro Manila    Quezon City  Metro Manila
# 3                 Current Address  Metro Manila    Diliman, QC  Metro Manila
# 4  Place of Work, Current Address  Metro Manila    Quezon City  Metro Manila
# 5                 Current Address      Pampanga   Angeles City      Pampanga
# 6                   Place of Work       Bulacan      Guiguinto  Metro Manila
# 7                   Place of Work       Benguet    Baguio City  Metro Manila
# 8                 Current Address  Metro Manila    Quezon City  Metro Manila
# 9                   Place of Work  Metro Manila       San Juan  Metro Manila
#
#    WorkCity_add      ConvStore_TD  ...            Supermarket_td  \
# 0   Mandaluyong  Less than 5 mins  ...         4 - 15 to 25 mins
# 1  Mandaluyong       5 to 10 mins  ...  5 - Greater than 25 mins
# 2   Quezon City  Less than 5 mins  ...         3 - 10 to 15 mins
# 3   Diliman, QC      5 to 10 mins  ...         4 - 15 to 25 mins
# 4   Quezon City      5 to 10 mins  ...         4 - 15 to 25 mins
# 5         Clark      5 to 10 mins  ...          2 - 5 to 10 mins
# 6   Quezon City     10 to 15 mins  ...          2 - 5 to 10 mins
# 7   Mandaluyong     10 to 15 mins  ...         4 - 15 to 25 mins
# 8   Quezon City  Less than 5 mins  ...         4 - 15 to 25 mins
# 9    Pasig City  Less than 5 mins  ...         3 - 10 to 15 mins
#
#                 Fastfood_td             CoffeeShop_td  \
# 0         3 - 10 to 15 mins         4 - 15 to 25 mins
# 1  5 - Greater than 25 mins         3 - 10 to 15 mins
# 2         3 - 10 to 15 mins         4 - 15 to 25 mins
# 3         4 - 15 to 25 mins         3 - 10 to 15 mins
# 4         4 - 15 to 25 mins         4 - 15 to 25 mins
# 5          2 - 5 to 10 mins          2 - 5 to 10 mins
# 6          2 - 5 to 10 mins         3 - 10 to 15 mins
# 7         4 - 15 to 25 mins  5 - Greater than 25 mins
# 8         4 - 15 to 25 mins         4 - 15 to 25 mins
# 9         3 - 10 to 15 mins         4 - 15 to 25 mins
#
#             StreetVendor_td           PublicMarket_td  \
# 0      1 - Less than 5 mins  5 - Greater than 25 mins
# 1         3 - 10 to 15 mins  5 - Greater than 25 mins
# 2      1 - Less than 5 mins          2 - 5 to 10 mins
# 3      1 - Less than 5 mins          2 - 5 to 10 mins
# 4          2 - 5 to 10 mins  5 - Greater than 25 mins
# 5          2 - 5 to 10 mins         3 - 10 to 15 mins
# 6         3 - 10 to 15 mins  5 - Greater than 25 mins
# 7  5 - Greater than 25 mins  5 - Greater than 25 mins
# 8      1 - Less than 5 mins      1 - Less than 5 mins
# 9          2 - 5 to 10 mins         4 - 15 to 25 mins
#
#                 Pharmacy_td                    Atm_td  \
# 0         4 - 15 to 25 mins         4 - 15 to 25 mins
# 1         4 - 15 to 25 mins         4 - 15 to 25 mins
# 2         3 - 10 to 15 mins         3 - 10 to 15 mins
# 3          2 - 5 to 10 mins         3 - 10 to 15 mins
# 4  5 - Greater than 25 mins         4 - 15 to 25 mins
# 5          2 - 5 to 10 mins          2 - 5 to 10 mins
# 6          2 - 5 to 10 mins          2 - 5 to 10 mins
# 7  5 - Greater than 25 mins  5 - Greater than 25 mins
# 8      1 - Less than 5 mins         4 - 15 to 25 mins
# 9         3 - 10 to 15 mins          2 - 5 to 10 mins
#
#           BillPayCounter_td Environment Nr_CityCenter
# 0  5 - Greater than 25 mins       Urban           Yes
# 1         4 - 15 to 25 mins       Urban            No
# 2         3 - 10 to 15 mins       Urban           Yes
# 3  5 - Greater than 25 mins       Urban           Yes
# 4         4 - 15 to 25 mins       Urban           Yes
# 5         3 - 10 to 15 mins       Urban           Yes
# 6         3 - 10 to 15 mins       Rural            No
# 7  5 - Greater than 25 mins       Urban           Yes
# 8  5 - Greater than 25 mins       Urban           Yes
# 9          2 - 5 to 10 mins       Urban           Yes
#
# [10 rows x 30 columns]

# %%
data03.describe() ##EDA Check on the only numerical variable.
# Out:
#              Age
# count  54.000000
# mean   26.777778
# std     5.745110
# min    18.000000
# 25%    24.000000
# 50%    25.000000
# 75%    28.000000
# max    56.000000

# %% [markdown]
# In exploring the data in excel, manual entry for the City of Residence/Work in the survey caused it to have multiple formats. We shall standardize their answers

# %%
print(data03['HomeCity_add'].unique()) #Displays Unique entries in the Home City Adddress column.

print(data03['WorkCity_add'].unique()) #Displays Unique entries in the Work City Adddress column.
# Out:
# ['Mandaluyong' 'Caloocan' 'Quezon' 'Angeles' 'Guiguinto' 'Baguio'
#  'San Juan' 'Sto. Domingo' 'Taytay' 'Taguig' 'Daet' 'Lipa' 'Bacoor'
#  'Las Pinas' 'Manila' 'Cainta' 'Quezon City' 'Imus' 'Pasig' 'Bay' 'Teresa'
#  'Marilao' 'Pulilan' 'Hermosa' 'Malabon' 'Pasay' 'Muntinlupa']
# ['Mandaluyong' 'Mandaluyong ' 'Quezon City' 'Diliman, QC' 'Clark'
#  'Pasig City' nan 'Mandaluyong city' 'Makati City' 'Quezon' 'Makati'
#  'Daet' 'General Trias' 'San Juan City' 'Taguig' 'Baguio City'
#  'QUEZON CITY' 'Quezon city' 'Pasig city' 'Taguig City' 'Muntinlupa']

# %% [markdown]
# **Finding: We can see that data are in different formats**

# %%
data03['HomeCity_add'] = data03['HomeCity_add'].str.replace(' City','')
data03['HomeCity_add'] = data03['HomeCity_add'].str.replace('qc','Quezon')
data03['HomeCity_add'] = data03['HomeCity_add'].str.replace('Diliman, QC','Quezon')
data03['HomeCity_add'] = data03['HomeCity_add'].str.replace('Sampaloc, Manila','Manila')
data03['HomeCity_add'] = data03['HomeCity_add'].str.replace('Hermosa ','Hermosa')
##Brute force replacement of cities in a different format was done due to the small size of the data set (54 entries)
data03['HomeCity_add'] = data03['HomeCity_add'].str.title() ##Convert All cities to title format

data03['WorkCity_add'] = data03['WorkCity_add'].str.lower()
data03['WorkCity_add'] = data03['WorkCity_add'].str.replace(' city','')
data03['WorkCity_add'] = data03['WorkCity_add'].str.replace('mandaluyong ','mandaluyong')
data03['WorkCity_add'] = data03['WorkCity_add'].str.replace('diliman, qc','quezon')
data03['WorkCity_add'] = data03['WorkCity_add'].fillna('Unemployed')
data03['WorkCity_add'] = data03['WorkCity_add'].str.title()

data03[['HomeCity_add','WorkCity_add']]
# Out:
#     HomeCity_add   WorkCity_add
# 0    Mandaluyong    Mandaluyong
# 1       Caloocan    Mandaluyong
# 2         Quezon         Quezon
# 3         Quezon         Quezon
# 4         Quezon         Quezon
# 5        Angeles          Clark
# 6      Guiguinto         Quezon
# 7         Baguio    Mandaluyong
# 8         Quezon         Quezon
# 9       San Juan          Pasig
# 10  Sto. Domingo          Pasig
# 11        Taytay     Unemployed
# 12        Taguig    Mandaluyong
# 13          Daet     Unemployed
# 14        Taytay    Mandaluyong
# 15          Lipa     Unemployed
# 16        Bacoor    Mandaluyong
# 17     Las Pinas    Mandaluyong
# 18        Manila         Makati
# 19        Quezon         Quezon
# 20        Quezon     Unemployed
# 21        Cainta         Quezon
# 22        Quezon         Makati
# 23          Imus     Unemployed
# 24        Quezon     Unemployed
# 25        Quezon         Quezon
# 26        Manila     Unemployed
# 27          Daet           Daet
# 28        Quezon         Quezon
# 29        Quezon         Quezon
# 30         Pasig    Mandaluyong
# 31         Pasig    Mandaluyong
# 32           Bay  General Trias
# 33        Quezon       San Juan
# 34        Quezon         Taguig
# 35        Teresa     Unemployed
# 36        Quezon         Quezon
# 37        Cainta         Quezon
# 38        Baguio         Baguio
# 39        Quezon         Quezon
# 40         Pasig    Mandaluyong
# 41       Marilao         Quezon
# 42        Quezon         Quezon
# 43       Pulilan    Mandaluyong
# 44   Mandaluyong          Pasig
# 45       Hermosa         Quezon
# 46       Malabon    Mandaluyong
# 47        Quezon         Taguig
# 48         Pasay    Mandaluyong
# 49        Quezon     Unemployed
# 50    Muntinlupa     Muntinlupa
# 51         Pasig         Quezon
# 52     Guiguinto          Pasig
# 53        Quezon     Unemployed

# %%
data03.to_csv('SP201_preprocessed.csv', index = False) ##write to file
preview = pd.read_csv('SP201_preprocessed.csv')
preview ###preview the preprocessed data
# Out:
#     Age                                  ConvStoresVisited  \
# 0    33  7-Eleven, Family Mart, Ministop, Alfamart, Lawson
# 1    26                                           7-Eleven
# 2    25                         7-Eleven, Ministop, Lawson
# 3    24          7-Eleven, Family Mart, Ministop, Alfamart
# 4    27                    7-Eleven, Family Mart, Ministop
# 5    24                    7-Eleven, Family Mart, Ministop
# 6    35                    7-Eleven, Family Mart, Ministop
# 7    27            7-Eleven, Family Mart, Ministop, Lawson
# 8    30                       7-Eleven, Ministop, Alfamart
# 9    26                                 7-Eleven, Ministop
# 10   24            7-Eleven, Family Mart, Ministop, Lawson
# 11   28                       7-Eleven, Ministop, Alfamart
# 12   28                                           Ministop
# 13   31                                 7-Eleven, Ministop
# 14   27                         7-Eleven, Ministop, Lawson
# 15   21                       7-Eleven, Ministop, Alfamart
# 16   24                         7-Eleven, Alfamart, Lawson
# 17   28          7-Eleven, Family Mart, Ministop, Alfamart
# 18   28  7-Eleven, Family Mart, Ministop, Alfamart, Lawson
# 19   56                                 7-Eleven, Ministop
# 20   23            7-Eleven, Family Mart, Ministop, Lawson
# 21   21  7-Eleven, Family Mart, Ministop, Alfamart, Cir...
# 22   32          7-Eleven, Family Mart, Ministop, Alfamart
# 23   21          7-Eleven, Family Mart, Ministop, Alfamart
# 24   21                    7-Eleven, Family Mart, Ministop
# 25   30                                 7-Eleven, Ministop
# 26   18                                 7-Eleven, Ministop
# 27   33                                 7-Eleven, Ministop
# 28   24                                 Ministop, Alfamart
# 29   24                                 7-Eleven, Ministop
# 30   25            7-Eleven, Family Mart, Ministop, Lawson
# 31   25            7-Eleven, Family Mart, Ministop, Lawson
# 32   25                                 7-Eleven, Ministop
# 33   25                    7-Eleven, Family Mart, Ministop
# 34   24                                 7-Eleven, Ministop
# 35   25                       7-Eleven, Ministop, Alfamart
# 36   25  7-Eleven, Family Mart, Ministop, Alfamart, Lawson
# 37   25                                 7-Eleven, Ministop
# 38   25                    7-Eleven, Family Mart, Ministop
# 39   26            7-Eleven, Family Mart, Ministop, Lawson
# 40   25                                             Lawson
# 41   27                                           7-Eleven
# 42   28                                 7-Eleven, Ministop
# 43   25                         7-Eleven, Ministop, Lawson
# 44   25  7-Eleven, Family Mart, Ministop, Alfamart, Cir...
# 45   25            7-Eleven, Family Mart, Ministop, Lawson
# 46   27  7-Eleven, Family Mart, Ministop, Alfamart, Lawson
# 47   26                                 7-Eleven, Ministop
# 48   24                      7-Eleven, Family Mart, Lawson
# 49   24                      7-Eleven, Family Mart, Lawson
# 50   39                      7-Eleven, Family Mart, Lawson
# 51   38                    7-Eleven, Family Mart, Ministop
# 52   25  7-Eleven, Family Mart, Ministop, Circle K, Lawson
# 53   19                              7-Eleven, Family Mart
#
#                                             Frequency  \
# 0     Fair (Twice a week to more than twice a month.)
# 1     Fair (Twice a week to more than twice a month.)
# 2   Rarely (On occasion only and less than twice a...
# 3     Fair (Twice a week to more than twice a month.)
# 4     Fair (Twice a week to more than twice a month.)
# 5     Fair (Twice a week to more than twice a month.)
# 6                     Seldom (Twice a month  or less)
# 7   Rarely (On occasion only and less than twice a...
# 8                     Seldom (Twice a month  or less)
# 9         Often (Every day to more than twice a week)
# 10        Often (Every day to more than twice a week)
# 11    Fair (Twice a week to more than twice a month.)
# 12    Fair (Twice a week to more than twice a month.)
# 13    Fair (Twice a week to more than twice a month.)
# 14    Fair (Twice a week to more than twice a month.)
# 15  Rarely (On occasion only and less than twice a...
# 16        Often (Every day to more than twice a week)
# 17                    Seldom (Twice a month  or less)
# 18  Rarely (On occasion only and less than twice a...
# 19  Rarely (On occasion only and less than twice a...
# 20    Fair (Twice a week to more than twice a month.)
# 21  Rarely (On occasion only and less than twice a...
# 22        Often (Every day to more than twice a week)
# 23  Rarely (On occasion only and less than twice a...
# 24                    Seldom (Twice a month  or less)
# 25    Fair (Twice a week to more than twice a month.)
# 26    Fair (Twice a week to more than twice a month.)
# 27                    Seldom (Twice a month  or less)
# 28    Fair (Twice a week to more than twice a month.)
# 29  Rarely (On occasion only and less than twice a...
# 30    Fair (Twice a week to more than twice a month.)
# 31                    Seldom (Twice a month  or less)
# 32                    Seldom (Twice a month  or less)
# 33    Fair (Twice a week to more than twice a month.)
# 34                    Seldom (Twice a month  or less)
# 35                    Seldom (Twice a month  or less)
# 36        Often (Every day to more than twice a week)
# 37    Fair (Twice a week to more than twice a month.)
# 38    Fair (Twice a week to more than twice a month.)
# 39  Rarely (On occasion only and less than twice a...
# 40  Rarely (On occasion only and less than twice a...
# 41        Often (Every day to more than twice a week)
# 42        Often (Every day to more than twice a week)
# 43    Fair (Twice a week to more than twice a month.)
# 44        Often (Every day to more than twice a week)
# 45                    Seldom (Twice a month  or less)
# 46    Fair (Twice a week to more than twice a month.)
# 47  Rarely (On occasion only and less than twice a...
# 48        Often (Every day to more than twice a week)
# 49  Rarely (On occasion only and less than twice a...
# 50  Rarely (On occasion only and less than twice a...
# 51                    Seldom (Twice a month  or less)
# 52        Often (Every day to more than twice a week)
# 53  Rarely (On occasion only and less than twice a...
#
#                                               Reasons  \
# 0   Purchase of Non-food/drink items, Purchase of ...
# 1    Purchase of food and drinks (consumed elsewhere)
# 2   Purchase of Non-food/drink items, Purchase of ...
# 3   Purchase of Non-food/drink items, Purchase of ...
# 4   Purchase of Non-food/drink items, Purchase of ...
# 5   Purchase of food and drinks (consumed elsewher...
# 6   Purchase of food and drinks (consumed elsewher...
# 7   Purchase of Non-food/drink items, Purchase of ...
# 8   Purchase of Non-food/drink items, Purchase of ...
# 9    Purchase of food and drinks (consumed elsewhere)
# 10   Purchase of food and drinks (consumed elsewhere)
# 11  Purchase of Non-food/drink items, Purchase of ...
# 12   Purchase of food and drinks (consumed elsewhere)
# 13  Purchase of Non-food/drink items, Purchase of ...
# 14  Purchase of food and drinks (consumed elsewher...
# 15  Purchase of Non-food/drink items, Purchase of ...
# 16  Purchase of food and drinks (consumed elsewher...
# 17  Purchase of Non-food/drink items, Purchase of ...
# 18  Purchase of Non-food/drink items, Purchase of ...
# 19   Purchase of food and drinks (consumed elsewhere)
# 20  Purchase of food and drinks (consumed elsewher...
# 21  Purchase of Non-food/drink items, Purchase of ...
# 22  Purchase of Non-food/drink items, Purchase of ...
# 23  Purchase of Non-food/drink items, Purchase of ...
# 24  Purchase of food and drinks (consumed elsewher...
# 25   Purchase of food and drinks (consumed elsewhere)
# 26  Purchase of food and drinks (consumed elsewher...
# 27   Purchase of food and drinks (consumed elsewhere)
# 28  Purchase of Non-food/drink items, Purchase of ...
# 29  Purchase of Non-food/drink items, Purchase of ...
# 30  Purchase of Non-food/drink items, Purchase of ...
# 31  Purchase of Non-food/drink items, Purchase of ...
# 32  Purchase of Non-food/drink items, Purchase of ...
# 33  Purchase of Non-food/drink items, Purchase of ...
# 34  Purchase of Non-food/drink items, Purchase of ...
# 35  Purchase of food and drinks (consumed elsewher...
# 36  Purchase of Non-food/drink items, Purchase of ...
# 37  Purchase of food and drinks (consumed elsewher...
# 38         Get food or drinks (Consumed at the store)
# 39   Purchase of food and drinks (consumed elsewhere)
# 40   Purchase of food and drinks (consumed elsewhere)
# 41  Purchase of food and drinks (consumed elsewher...
# 42  Purchase of food and drinks (consumed elsewher...
# 43  Purchase of Non-food/drink items, Purchase of ...
# 44  Purchase of Non-food/drink items, Purchase of ...
# 45  Purchase of food and drinks (consumed elsewher...
# 46  Purchase of Non-food/drink items, Purchase of ...
# 47  Get food or drinks (Consumed at the store), Ot...
# 48  Purchase of food and drinks (consumed elsewher...
# 49  Purchase of food and drinks (consumed elsewher...
# 50  Purchase of Non-food/drink items, Purchase of ...
# 51   Purchase of food and drinks (consumed elsewhere)
# 52  Purchase of food and drinks (consumed elsewher...
# 53  Purchase of food and drinks (consumed elsewher...
#
#                   ConvStore_nearto     HomeProv_add  HomeCity_add  \
# 0   Place of Work, Current Address     Metro Manila   Mandaluyong
# 1                    Place of Work     Metro Manila      Caloocan
# 2   Place of Work, Current Address     Metro Manila        Quezon
# 3                  Current Address     Metro Manila        Quezon
# 4   Place of Work, Current Address     Metro Manila        Quezon
# 5                  Current Address         Pampanga       Angeles
# 6                    Place of Work          Bulacan     Guiguinto
# 7                    Place of Work          Benguet        Baguio
# 8                  Current Address     Metro Manila        Quezon
# 9                    Place of Work     Metro Manila      San Juan
# 10  Place of Work, Current Address            Albay  Sto. Domingo
# 11                 Current Address            Rizal        Taytay
# 12                   Place of Work     Metro Manila        Taguig
# 13                 Current Address  Camarines Norte          Daet
# 14  Place of Work, Current Address            Rizal        Taytay
# 15                 Current Address         Batangas          Lipa
# 16  Place of Work, Current Address           Cavite        Bacoor
# 17  Place of Work, Current Address     Metro Manila     Las Pinas
# 18                 Current Address     Metro Manila        Manila
# 19                 Current Address     Metro Manila        Quezon
# 20                 Current Address     Metro Manila        Quezon
# 21  Place of Work, Current Address            Rizal        Cainta
# 22  Place of Work, Current Address     Metro Manila        Quezon
# 23                 Current Address           Cavite          Imus
# 24                 Current Address     Metro Manila        Quezon
# 25                 Current Address     Metro Manila        Quezon
# 26                 Current Address     Metro Manila        Manila
# 27                 Current Address  Camarines Norte          Daet
# 28  Place of Work, Current Address     Metro Manila        Quezon
# 29                 Current Address     Metro Manila        Quezon
# 30                   Place of Work     Metro Manila         Pasig
# 31  Place of Work, Current Address     Metro Manila         Pasig
# 32  Place of Work, Current Address           Laguna           Bay
# 33  Place of Work, Current Address     Metro Manila        Quezon
# 34                   Place of Work     Metro Manila        Quezon
# 35                 Current Address            Rizal        Teresa
# 36  Place of Work, Current Address     Metro Manila        Quezon
# 37                   Place of Work            Rizal        Cainta
# 38                   Place of Work          Benguet        Baguio
# 39  Place of Work, Current Address     Metro Manila        Quezon
# 40                   Place of Work     Metro Manila         Pasig
# 41                   Place of Work          Bulacan       Marilao
# 42                   Place of Work     Metro Manila        Quezon
# 43  Place of Work, Current Address          Bulacan       Pulilan
# 44  Place of Work, Current Address     Metro Manila   Mandaluyong
# 45  Place of Work, Current Address           Bataan       Hermosa
# 46  Place of Work, Current Address     Metro Manila       Malabon
# 47                 Current Address     Metro Manila        Quezon
# 48  Place of Work, Current Address     Metro Manila         Pasay
# 49                 Current Address     Metro Manila        Quezon
# 50                   Place of Work     Metro Manila    Muntinlupa
# 51                 Current Address     Metro Manila         Pasig
# 52                   Place of Work          Bulacan     Guiguinto
# 53                 Current Address     Metro Manila        Quezon
#
#        WorkProv_add   WorkCity_add         ConvStore_TD  ...  \
# 0      Metro Manila    Mandaluyong     Less than 5 mins  ...
# 1      Metro Manila    Mandaluyong         5 to 10 mins  ...
# 2      Metro Manila         Quezon     Less than 5 mins  ...
# 3      Metro Manila         Quezon         5 to 10 mins  ...
# 4      Metro Manila         Quezon         5 to 10 mins  ...
# 5          Pampanga          Clark         5 to 10 mins  ...
# 6      Metro Manila         Quezon        10 to 15 mins  ...
# 7      Metro Manila    Mandaluyong        10 to 15 mins  ...
# 8      Metro Manila         Quezon     Less than 5 mins  ...
# 9      Metro Manila          Pasig     Less than 5 mins  ...
# 10     Metro Manila          Pasig     Less than 5 mins  ...
# 11       Unemployed     Unemployed     Less than 5 mins  ...
# 12     Metro Manila    Mandaluyong         5 to 10 mins  ...
# 13       Unemployed     Unemployed     Less than 5 mins  ...
# 14     Metro Manila    Mandaluyong         5 to 10 mins  ...
# 15       Unemployed     Unemployed  Greater than 25mins  ...
# 16     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 17     Metro Manila    Mandaluyong         5 to 10 mins  ...
# 18     Metro Manila         Makati         5 to 10 mins  ...
# 19     Metro Manila         Quezon     Less than 5 mins  ...
# 20       Unemployed     Unemployed     Less than 5 mins  ...
# 21     Metro Manila         Quezon        10 to 15 mins  ...
# 22     Metro Manila         Makati     Less than 5 mins  ...
# 23       Unemployed     Unemployed     Less than 5 mins  ...
# 24       Unemployed     Unemployed        10 to 15 mins  ...
# 25     Metro Manila         Quezon     Less than 5 mins  ...
# 26       Unemployed     Unemployed     Less than 5 mins  ...
# 27  Camarines Norte           Daet     Less than 5 mins  ...
# 28     Metro Manila         Quezon     Less than 5 mins  ...
# 29     Metro Manila         Quezon        10 to 15 mins  ...
# 30     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 31     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 32           Cavite  General Trias         5 to 10 mins  ...
# 33     Metro Manila       San Juan         5 to 10 mins  ...
# 34     Metro Manila         Taguig     Less than 5 mins  ...
# 35     Metro Manila     Unemployed        10 to 15 mins  ...
# 36     Metro Manila         Quezon     Less than 5 mins  ...
# 37     Metro Manila         Quezon     Less than 5 mins  ...
# 38          Benguet         Baguio        15 to 25 mins  ...
# 39     Metro Manila         Quezon         5 to 10 mins  ...
# 40     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 41     Metro Manila         Quezon     Less than 5 mins  ...
# 42     Metro Manila         Quezon        15 to 25 mins  ...
# 43     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 44     Metro Manila          Pasig     Less than 5 mins  ...
# 45     Metro Manila         Quezon     Less than 5 mins  ...
# 46     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 47     Metro Manila         Taguig         5 to 10 mins  ...
# 48     Metro Manila    Mandaluyong     Less than 5 mins  ...
# 49     Metro Manila     Unemployed        10 to 15 mins  ...
# 50     Metro Manila     Muntinlupa     Less than 5 mins  ...
# 51     Metro Manila         Quezon        15 to 25 mins  ...
# 52     Metro Manila          Pasig     Less than 5 mins  ...
# 53       Unemployed     Unemployed     Less than 5 mins  ...
#
#               Supermarket_td               Fastfood_td  \
# 0          4 - 15 to 25 mins         3 - 10 to 15 mins
# 1   5 - Greater than 25 mins  5 - Greater than 25 mins
# 2          3 - 10 to 15 mins         3 - 10 to 15 mins
# 3          4 - 15 to 25 mins         4 - 15 to 25 mins
# 4          4 - 15 to 25 mins         4 - 15 to 25 mins
# 5           2 - 5 to 10 mins          2 - 5 to 10 mins
# 6           2 - 5 to 10 mins          2 - 5 to 10 mins
# 7          4 - 15 to 25 mins         4 - 15 to 25 mins
# 8          4 - 15 to 25 mins         4 - 15 to 25 mins
# 9          3 - 10 to 15 mins         3 - 10 to 15 mins
# 10          2 - 5 to 10 mins         4 - 15 to 25 mins
# 11         3 - 10 to 15 mins         3 - 10 to 15 mins
# 12         3 - 10 to 15 mins          2 - 5 to 10 mins
# 13          2 - 5 to 10 mins          2 - 5 to 10 mins
# 14          2 - 5 to 10 mins          2 - 5 to 10 mins
# 15  5 - Greater than 25 mins  5 - Greater than 25 mins
# 16          2 - 5 to 10 mins          2 - 5 to 10 mins
# 17          2 - 5 to 10 mins          2 - 5 to 10 mins
# 18         4 - 15 to 25 mins         4 - 15 to 25 mins
# 19         3 - 10 to 15 mins         3 - 10 to 15 mins
# 20      1 - Less than 5 mins         4 - 15 to 25 mins
# 21         4 - 15 to 25 mins         3 - 10 to 15 mins
# 22         3 - 10 to 15 mins          2 - 5 to 10 mins
# 23         4 - 15 to 25 mins          2 - 5 to 10 mins
# 24         4 - 15 to 25 mins         3 - 10 to 15 mins
# 25         3 - 10 to 15 mins         3 - 10 to 15 mins
# 26         4 - 15 to 25 mins      1 - Less than 5 mins
# 27          2 - 5 to 10 mins         3 - 10 to 15 mins
# 28  5 - Greater than 25 mins         4 - 15 to 25 mins
# 29         4 - 15 to 25 mins         4 - 15 to 25 mins
# 30         3 - 10 to 15 mins          2 - 5 to 10 mins
# 31         4 - 15 to 25 mins         3 - 10 to 15 mins
# 32  5 - Greater than 25 mins         3 - 10 to 15 mins
# 33         4 - 15 to 25 mins         4 - 15 to 25 mins
# 34  5 - Greater than 25 mins         3 - 10 to 15 mins
# 35         4 - 15 to 25 mins         4 - 15 to 25 mins
# 36         3 - 10 to 15 mins         3 - 10 to 15 mins
# 37         3 - 10 to 15 mins         3 - 10 to 15 mins
# 38         3 - 10 to 15 mins         3 - 10 to 15 mins
# 39         3 - 10 to 15 mins         3 - 10 to 15 mins
# 40         3 - 10 to 15 mins         3 - 10 to 15 mins
# 41  5 - Greater than 25 mins         3 - 10 to 15 mins
# 42         3 - 10 to 15 mins      1 - Less than 5 mins
# 43         4 - 15 to 25 mins         4 - 15 to 25 mins
# 44         3 - 10 to 15 mins         4 - 15 to 25 mins
# 45  5 - Greater than 25 mins  5 - Greater than 25 mins
# 46          2 - 5 to 10 mins      1 - Less than 5 mins
# 47          2 - 5 to 10 mins         3 - 10 to 15 mins
# 48         4 - 15 to 25 mins         4 - 15 to 25 mins
# 49          2 - 5 to 10 mins          2 - 5 to 10 mins
# 50         4 - 15 to 25 mins         4 - 15 to 25 mins
# 51         4 - 15 to 25 mins         4 - 15 to 25 mins
# 52         3 - 10 to 15 mins          2 - 5 to 10 mins
# 53          2 - 5 to 10 mins          2 - 5 to 10 mins
#
#                CoffeeShop_td           StreetVendor_td  \
# 0          4 - 15 to 25 mins      1 - Less than 5 mins
# 1          3 - 10 to 15 mins         3 - 10 to 15 mins
# 2          4 - 15 to 25 mins      1 - Less than 5 mins
# 3          3 - 10 to 15 mins      1 - Less than 5 mins
# 4          4 - 15 to 25 mins          2 - 5 to 10 mins
# 5           2 - 5 to 10 mins          2 - 5 to 10 mins
# 6          3 - 10 to 15 mins         3 - 10 to 15 mins
# 7   5 - Greater than 25 mins  5 - Greater than 25 mins
# 8          4 - 15 to 25 mins      1 - Less than 5 mins
# 9          4 - 15 to 25 mins          2 - 5 to 10 mins
# 10          2 - 5 to 10 mins      1 - Less than 5 mins
# 11         3 - 10 to 15 mins      1 - Less than 5 mins
# 12          2 - 5 to 10 mins         3 - 10 to 15 mins
# 13      1 - Less than 5 mins      1 - Less than 5 mins
# 14          2 - 5 to 10 mins      1 - Less than 5 mins
# 15  5 - Greater than 25 mins          2 - 5 to 10 mins
# 16          2 - 5 to 10 mins      1 - Less than 5 mins
# 17          2 - 5 to 10 mins          2 - 5 to 10 mins
# 18  5 - Greater than 25 mins         4 - 15 to 25 mins
# 19         3 - 10 to 15 mins      1 - Less than 5 mins
# 20          2 - 5 to 10 mins          2 - 5 to 10 mins
# 21          2 - 5 to 10 mins          2 - 5 to 10 mins
# 22         4 - 15 to 25 mins          2 - 5 to 10 mins
# 23         4 - 15 to 25 mins          2 - 5 to 10 mins
# 24         3 - 10 to 15 mins      1 - Less than 5 mins
# 25         3 - 10 to 15 mins  5 - Greater than 25 mins
# 26  5 - Greater than 25 mins      1 - Less than 5 mins
# 27      1 - Less than 5 mins         4 - 15 to 25 mins
# 28         4 - 15 to 25 mins  5 - Greater than 25 mins
# 29          2 - 5 to 10 mins          2 - 5 to 10 mins
# 30          2 - 5 to 10 mins         3 - 10 to 15 mins
# 31         4 - 15 to 25 mins          2 - 5 to 10 mins
# 32         4 - 15 to 25 mins          2 - 5 to 10 mins
# 33         3 - 10 to 15 mins          2 - 5 to 10 mins
# 34         3 - 10 to 15 mins      1 - Less than 5 mins
# 35         4 - 15 to 25 mins         3 - 10 to 15 mins
# 36         4 - 15 to 25 mins         3 - 10 to 15 mins
# 37         3 - 10 to 15 mins      1 - Less than 5 mins
# 38         3 - 10 to 15 mins          2 - 5 to 10 mins
# 39         3 - 10 to 15 mins          2 - 5 to 10 mins
# 40         3 - 10 to 15 mins      1 - Less than 5 mins
# 41  5 - Greater than 25 mins          2 - 5 to 10 mins
# 42         4 - 15 to 25 mins      1 - Less than 5 mins
# 43         4 - 15 to 25 mins         3 - 10 to 15 mins
# 44         4 - 15 to 25 mins         4 - 15 to 25 mins
# 45  5 - Greater than 25 mins          2 - 5 to 10 mins
# 46          2 - 5 to 10 mins      1 - Less than 5 mins
# 47         3 - 10 to 15 mins          2 - 5 to 10 mins
# 48         4 - 15 to 25 mins         3 - 10 to 15 mins
# 49          2 - 5 to 10 mins          2 - 5 to 10 mins
# 50         4 - 15 to 25 mins         3 - 10 to 15 mins
# 51         4 - 15 to 25 mins      1 - Less than 5 mins
# 52  5 - Greater than 25 mins          2 - 5 to 10 mins
# 53          2 - 5 to 10 mins         3 - 10 to 15 mins
#
#              PublicMarket_td               Pharmacy_td  \
# 0   5 - Greater than 25 mins         4 - 15 to 25 mins
# 1   5 - Greater than 25 mins         4 - 15 to 25 mins
# 2           2 - 5 to 10 mins         3 - 10 to 15 mins
# 3           2 - 5 to 10 mins          2 - 5 to 10 mins
# 4   5 - Greater than 25 mins  5 - Greater than 25 mins
# 5          3 - 10 to 15 mins          2 - 5 to 10 mins
# 6   5 - Greater than 25 mins          2 - 5 to 10 mins
# 7   5 - Greater than 25 mins  5 - Greater than 25 mins
# 8       1 - Less than 5 mins      1 - Less than 5 mins
# 9          4 - 15 to 25 mins         3 - 10 to 15 mins
# 10          2 - 5 to 10 mins          2 - 5 to 10 mins
# 11          2 - 5 to 10 mins      1 - Less than 5 mins
# 12         4 - 15 to 25 mins          2 - 5 to 10 mins
# 13          2 - 5 to 10 mins          2 - 5 to 10 mins
# 14         3 - 10 to 15 mins          2 - 5 to 10 mins
# 15  5 - Greater than 25 mins  5 - Greater than 25 mins
# 16      1 - Less than 5 mins      1 - Less than 5 mins
# 17         3 - 10 to 15 mins          2 - 5 to 10 mins
# 18         4 - 15 to 25 mins         4 - 15 to 25 mins
# 19         3 - 10 to 15 mins         3 - 10 to 15 mins
# 20  5 - Greater than 25 mins      1 - Less than 5 mins
# 21          2 - 5 to 10 mins         3 - 10 to 15 mins
# 22          2 - 5 to 10 mins          2 - 5 to 10 mins
# 23         4 - 15 to 25 mins         4 - 15 to 25 mins
# 24         3 - 10 to 15 mins         3 - 10 to 15 mins
# 25         3 - 10 to 15 mins         3 - 10 to 15 mins
# 26      1 - Less than 5 mins          2 - 5 to 10 mins
# 27         3 - 10 to 15 mins         3 - 10 to 15 mins
# 28  5 - Greater than 25 mins         4 - 15 to 25 mins
# 29         3 - 10 to 15 mins          2 - 5 to 10 mins
# 30         4 - 15 to 25 mins         4 - 15 to 25 mins
# 31         4 - 15 to 25 mins         3 - 10 to 15 mins
# 32         4 - 15 to 25 mins          2 - 5 to 10 mins
# 33  5 - Greater than 25 mins         4 - 15 to 25 mins
# 34  5 - Greater than 25 mins         3 - 10 to 15 mins
# 35         3 - 10 to 15 mins         4 - 15 to 25 mins
# 36  5 - Greater than 25 mins         4 - 15 to 25 mins
# 37         3 - 10 to 15 mins         3 - 10 to 15 mins
# 38         3 - 10 to 15 mins         3 - 10 to 15 mins
# 39  5 - Greater than 25 mins         3 - 10 to 15 mins
# 40          2 - 5 to 10 mins          2 - 5 to 10 mins
# 41  5 - Greater than 25 mins  5 - Greater than 25 mins
# 42  5 - Greater than 25 mins         3 - 10 to 15 mins
# 43          2 - 5 to 10 mins          2 - 5 to 10 mins
# 44         4 - 15 to 25 mins         3 - 10 to 15 mins
# 45          2 - 5 to 10 mins          2 - 5 to 10 mins
# 46          2 - 5 to 10 mins      1 - Less than 5 mins
# 47         3 - 10 to 15 mins         3 - 10 to 15 mins
# 48         4 - 15 to 25 mins          2 - 5 to 10 mins
# 49         3 - 10 to 15 mins          2 - 5 to 10 mins
# 50         4 - 15 to 25 mins         4 - 15 to 25 mins
# 51  5 - Greater than 25 mins         4 - 15 to 25 mins
# 52          2 - 5 to 10 mins         4 - 15 to 25 mins
# 53         3 - 10 to 15 mins          2 - 5 to 10 mins
#
#                       Atm_td         BillPayCounter_td Environment  \
# 0          4 - 15 to 25 mins  5 - Greater than 25 mins       Urban
# 1          4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 2          3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 3          3 - 10 to 15 mins  5 - Greater than 25 mins       Urban
# 4          4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 5           2 - 5 to 10 mins         3 - 10 to 15 mins       Urban
# 6           2 - 5 to 10 mins         3 - 10 to 15 mins       Rural
# 7   5 - Greater than 25 mins  5 - Greater than 25 mins       Urban
# 8          4 - 15 to 25 mins  5 - Greater than 25 mins       Urban
# 9           2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 10         4 - 15 to 25 mins         4 - 15 to 25 mins       Rural
# 11          2 - 5 to 10 mins         3 - 10 to 15 mins       Urban
# 12          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 13          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 14          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 15  5 - Greater than 25 mins  5 - Greater than 25 mins       Rural
# 16          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 17          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 18         4 - 15 to 25 mins  5 - Greater than 25 mins       Urban
# 19         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 20      1 - Less than 5 mins      1 - Less than 5 mins       Urban
# 21  5 - Greater than 25 mins  5 - Greater than 25 mins       Urban
# 22          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 23         4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 24         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 25      1 - Less than 5 mins      1 - Less than 5 mins       Urban
# 26      1 - Less than 5 mins  5 - Greater than 25 mins       Urban
# 27         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 28      1 - Less than 5 mins  5 - Greater than 25 mins       Urban
# 29         3 - 10 to 15 mins         4 - 15 to 25 mins       Urban
# 30  5 - Greater than 25 mins  5 - Greater than 25 mins       Rural
# 31         4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 32         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 33          2 - 5 to 10 mins  5 - Greater than 25 mins       Urban
# 34         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 35         4 - 15 to 25 mins         4 - 15 to 25 mins       Rural
# 36         4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 37         4 - 15 to 25 mins         3 - 10 to 15 mins       Urban
# 38         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 39         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 40         4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 41  5 - Greater than 25 mins  5 - Greater than 25 mins       Urban
# 42      1 - Less than 5 mins         3 - 10 to 15 mins       Urban
# 43  5 - Greater than 25 mins  5 - Greater than 25 mins       Rural
# 44         4 - 15 to 25 mins         4 - 15 to 25 mins       Urban
# 45         3 - 10 to 15 mins  5 - Greater than 25 mins       Rural
# 46      1 - Less than 5 mins          2 - 5 to 10 mins       Urban
# 47         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
# 48  5 - Greater than 25 mins  5 - Greater than 25 mins       Urban
# 49          2 - 5 to 10 mins          2 - 5 to 10 mins       Urban
# 50         4 - 15 to 25 mins         3 - 10 to 15 mins       Urban
# 51         4 - 15 to 25 mins  5 - Greater than 25 mins       Rural
# 52         3 - 10 to 15 mins         4 - 15 to 25 mins       Rural
# 53         3 - 10 to 15 mins         3 - 10 to 15 mins       Urban
#
#    Nr_CityCenter
# 0            Yes
# 1             No
# 2            Yes
# 3            Yes
# 4            Yes
# 5            Yes
# 6             No
# 7            Yes
# 8            Yes
# 9            Yes
# 10            No
# 11            No
# 12           Yes
# 13           Yes
# 14            No
# 15            No
# 16           Yes
# 17           Yes
# 18            No
# 19           Yes
# 20           Yes
# 21            No
# 22           Yes
# 23            No
# 24            No
# 25           Yes
# 26            No
# 27           Yes
# 28           Yes
# 29           Yes
# 30           Yes
# 31            No
# 32           Yes
# 33           Yes
# 34            No
# 35            No
# 36           Yes
# 37           Yes
# 38           Yes
# 39           Yes
# 40           Yes
# 41           Yes
# 42           Yes
# 43           Yes
# 44           Yes
# 45            No
# 46           Yes
# 47           Yes
# 48           Yes
# 49           Yes
# 50           Yes
# 51           Yes
# 52            No
# 53           Yes
#
# [54 rows x 30 columns]

# %% [markdown]
# **Note: Other data can be preprocessed via feature engineering which is a week 5 lesson and will not be applied here in week 4**
