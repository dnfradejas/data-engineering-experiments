# %%
import pandas as pd

# %%
#loading the csv file
nwdata = pd.read_csv(r'C:\Users\noelb\Downloads\sales.csv')
nwdata
# Out:
#      Transaction_date   Product Price Payment_Type               Name  \
# 0     01/02/2009 6:17  Product1  1200   Mastercard           carolina
# 1     01/02/2009 4:53  Product1  1200         Visa             Betina
# 2    01/02/2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3    01/03/2009 14:44  Product1  1200         Visa              Gouya
# 4    01/04/2009 12:56  Product2  3600         Visa            Gerd W
# ..                ...       ...   ...          ...                ...
# 995   1/22/2009 14:25  Product1  1200         Visa         Hans-Joerg
# 996    1/28/2009 5:36  Product2  3600         Visa         Christiane
# 997   01/01/2009 4:24  Product3  7500         Amex             Pamela
# 998  01/08/2009 11:55  Product1  1200       Diners              julie
# 999  01/12/2009 21:30  Product1  1200         Visa             Julia
#
#                              City             State         Country  \
# ...

# %%
#task 1 : Give an initial charazterization of the entire data frame
nwdata.describe(include = 'all')
# Out:
#         Transaction_date   Product Price Payment_Type   Name    City    State  \
# count                997       997   999          997   1000     996      995
# unique               979         4    12            4    761     752      204
# top     01/12/2009 13:41  Product1  1200         Visa  Sarah  London  England
# freq                   2       846   838          520     11      19       84
# mean                 NaN       NaN   NaN          NaN    NaN     NaN      NaN
# std                  NaN       NaN   NaN          NaN    NaN     NaN      NaN
# min                  NaN       NaN   NaN          NaN    NaN     NaN      NaN
# 25%                  NaN       NaN   NaN          NaN    NaN     NaN      NaN
# 50%                  NaN       NaN   NaN          NaN    NaN     NaN      NaN
# 75%                  NaN       NaN   NaN          NaN    NaN     NaN      NaN
# max                  NaN       NaN   NaN          NaN    NaN     NaN      NaN
#
# ...

# %%
#task 2: remove duplicate row values
nwdata = nwdata.drop_duplicates()
nwdata
# Out:
#      Transaction_date   Product Price Payment_Type               Name  \
# 0     01/02/2009 6:17  Product1  1200   Mastercard           carolina
# 1     01/02/2009 4:53  Product1  1200         Visa             Betina
# 2    01/02/2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3    01/03/2009 14:44  Product1  1200         Visa              Gouya
# 4    01/04/2009 12:56  Product2  3600         Visa            Gerd W
# ..                ...       ...   ...          ...                ...
# 995   1/22/2009 14:25  Product1  1200         Visa         Hans-Joerg
# 996    1/28/2009 5:36  Product2  3600         Visa         Christiane
# 997   01/01/2009 4:24  Product3  7500         Amex             Pamela
# 998  01/08/2009 11:55  Product1  1200       Diners              julie
# 999  01/12/2009 21:30  Product1  1200         Visa             Julia
#
#                              City             State         Country  \
# ...

# %%
#task 3: Express price in thousands
nwdata['Price']
# Out:
# 0      1200
# 1      1200
# 2      1200
# 3      1200
# 4      3600
#        ...
# 995    1200
# 996    3600
# 997    7500
# 998    1200
# 999    1200
# Name: Price, Length: 993, dtype: object

# %%
print(nwdata.dtypes)
# Out:
# Transaction_date     object
# Product              object
# Price                object
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# dtype: object

# %%
#Price column is of object type, convert it to float
nwdata['Price'] = pd.to_numeric(nwdata['Price'],errors='coerce')

# %%
print(nwdata.dtypes)
# Out:
# Transaction_date     object
# Product              object
# Price               float64
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# dtype: object

# %%
#Express price in thousands
nwdata['Price'] = nwdata['Price']/1000

# %%
nwdata
# Out:
#      Transaction_date   Product  Price Payment_Type               Name  \
# 0     01/02/2009 6:17  Product1    1.2   Mastercard           carolina
# 1     01/02/2009 4:53  Product1    1.2         Visa             Betina
# 2    01/02/2009 13:08  Product1    1.2   Mastercard  Federica e Andrea
# 3    01/03/2009 14:44  Product1    1.2         Visa              Gouya
# 4    01/04/2009 12:56  Product2    3.6         Visa            Gerd W
# ..                ...       ...    ...          ...                ...
# 995   1/22/2009 14:25  Product1    1.2         Visa         Hans-Joerg
# 996    1/28/2009 5:36  Product2    3.6         Visa         Christiane
# 997   01/01/2009 4:24  Product3    7.5         Amex             Pamela
# 998  01/08/2009 11:55  Product1    1.2       Diners              julie
# 999  01/12/2009 21:30  Product1    1.2         Visa             Julia
#
#                              City             State         Country  \
# ...

# %%
#task 4: Select name, city and country data of product 2 bought by customers from
#united states and paid thru Visa or Mastercard. Store the selected data in empty.csv file

filter = nwdata[['Name','City','Country']]

task4data = filter[(nwdata.Product == 'Product2') & (nwdata.Country == 'United States') &((nwdata.Payment_Type == 'Mastercard')|(nwdata.Payment_Type == 'Visa'))]

task4data
# Out:
#                Name                          City        Country
# 4           Gerd W   Cahaba Heights                United States
# 45          Anabela  Flossmoor                     United States
# 47      Christiane   Delray Beach                  United States
# 86            Valda  Irvine                        United States
# 159         Therese  Los Angeles                   United States
# 160         Abdul-L  New York                      United States
# 161           heidi  Saint Paul                    United States
# 162         jiyoung  New York                      United States
# 184             Bev  San Ramon                     United States
# 206       Patricia   Portola Valley                United States
# 228        Rosemary  Jacksonville                  United States
# 242     Anja Langer  Saint Paul                    United States
# 265           Cindy  Englewood                     United States
# ...

# %%
#Store the selected data to empty.csv
task4data.to_csv(r'E:\empty.csv', index = False)

# %%
#Loading the task 4 csv file
pd.read_csv(r'E:\empty.csv')
# Out:
#               Name                          City        Country
# 0          Gerd W   Cahaba Heights                United States
# 1          Anabela  Flossmoor                     United States
# 2      Christiane   Delray Beach                  United States
# 3            Valda  Irvine                        United States
# 4          Therese  Los Angeles                   United States
# 5          Abdul-L  New York                      United States
# 6            heidi  Saint Paul                    United States
# 7          jiyoung  New York                      United States
# 8              Bev  San Ramon                     United States
# 9        Patricia   Portola Valley                United States
# 10        Rosemary  Jacksonville                  United States
# 11     Anja Langer  Saint Paul                    United States
# 12           Cindy  Englewood                     United States
# 13          shelby  Plantation                    United States
# ...

# %%
#task 5: Select name, price, city, state and country data of product 2 bought by customers from 
#New York and paid thru Mastercard. Store the selected data in empty_1.csv file

filter = nwdata[['Name', 'Price', 'City', 'State', 'Country']]

# %%
# Checking the data
nwdata.City
# Out:
# 0                          Basildon
# 1      Parkville
# 2      Astoria
# 3                            Echuca
# 4      Cahaba Heights
#                    ...
# 995                         Belfast
# 996                     Black River
# 997    Skaneateles
# 998                       Haverhill
# 999    Madison
# Name: City, Length: 1000, dtype: object

# %%
#listing all the data from the column City
nwdata['City'].to_list()
# Out:
# ['Basildon',
#  'Parkville                   ',
#  'Astoria                     ',
#  'Echuca',
#  'Cahaba Heights              ',
#  'Mickleton                   ',
#  'Peoria                      ',
#  'Martin                      ',
#  'Martin                      ',
#  'Tel Aviv',
#  'Chatou',
#  'Chatou',
#  'New York                    ',
#  'Eindhoven',
#  'Shavano Park                ',
#  'Eagle                       ',
#  'Riverside                   ',
#  'Julianstown',
#  'Ottawa',
#  'Hyderabad',
#  'London',
#  'Salt Lake City              ',
#  'Manchester',
#  'Ballynora',
#  'Roodepoort',
#  'Chula Vista                 ',
#  'Kuopio',
#  'Sugar Land                  ',
#  'New York                    ',
#  'London',
#  'Morton                      ',
#  'Los Gatos                   ',
#  'New York                    ',
#  'Miami                       ',
#  'Vesenaz',
#  'Brooklyn                    ',
#  'Badhoevedorp',
#  'Reston                      ',
# ...

# %%
#Values in these column has white spaces

nwdata[nwdata.City == 'New York                    ']
nwdata.City = nwdata.City.str.strip()

# %%
#task 5: Select name, price, city, state and country data of product 2 bought by customers from 
#New York and paid thru Mastercard. Store the selected data in empty_1.csv file

filter[(nwdata.Product=='Product2') & (nwdata.City=='New York') & (nwdata.Payment_Type=='Mastercard')]
# Out:
# Empty DataFrame
# Columns: [Name, Price, City, State, Country]
# Index: []

# %%
#Double checking, there are only 2 rows from New York and Product2 but the Payment type is of Visa
#Hence no data found that satisfies the criteria

nwdata[(nwdata.City=='New York')&(nwdata.Product == 'Product2')]
# Out:
#     Transaction_date   Product  Price Payment_Type     Name      City State  \
# 160  1/18/2009 17:04  Product2    3.6         Visa  Abdul-L  New York    NY
# 162  1/18/2009 17:39  Product2    3.6         Visa  jiyoung  New York    NY
#
#            Country  Account_Created       Last_Login  Latitude  Longitude
# 160  United States  1/18/2009 16:58  1/18/2009 16:58  40.71417  -74.00639
# 162  United States  1/18/2009 17:34  1/18/2009 17:34  40.71417  -74.00639
